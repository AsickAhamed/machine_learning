# %% [markdown]
# <a href="https://colab.research.google.com/github/AsickAhamed/machine_learning/blob/dev/linear_Regression_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary libs
import pandas as pd
import numpy as np

# %%
# loading data
x = np.array([])
y = np.array([])

# %%
# cost function
def compute_cost(x,y,w,b):

  f_x = (w * x) + b
  cost = np.sum((f_x - y) ** 2)
  return cost / (2 * len(x))

# %%
def compute_gradient(x,y,w,b):
